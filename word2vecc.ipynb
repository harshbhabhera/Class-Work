# %% [markdown]
# <a href="https://colab.research.google.com/github/harshbhabhera/Class-Work/blob/master/word2vecc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from nltk.corpus import wordnet

# %%
df = pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz", lines=True)
df.head()
# Out:
#        reviewerID        asin  ... unixReviewTime   reviewTime
# 0  A32T2H8150OJLU  B00000JBLH  ...     1094169600   09 3, 2004
# 1  A3MAFS04ZABRGO  B00000JBLH  ...     1197676800  12 15, 2007
# 2  A1F1A0QQP2XVH5  B00000JBLH  ...     1293840000   01 1, 2011
# 3   A49R5DBXXQDE5  B00000JBLH  ...     1145404800  04 19, 2006
# 4  A2XRMQA6PJ5ZJ8  B00000JBLH  ...     1375574400   08 4, 2013
#
# [5 rows x 9 columns]

# %%
def word_count(str):
  wordcount =dict()
  words=str.split()
  for word in words:
    if word in wordcount:
      wordcount[word]+=1
    else:
      wordcount[word]=1
  return wordcount

# %%
def letters(string):
    vowels = 0
    vowels_list = ['a', 'e', 'i', 'o', 'u']
    consonants = 0
    words = len(string.split())
    for i in range(0, len(string)):  
            ch = string[i]  
            ch = ch.lower()
            if (ch >= 'a' and ch <= 'z'):
             if ch in vowels_list: 
                vowels += 1
             else: 
                consonants += 1
          
    count = {'vowels': vowels, 'consonants': consonants, 'words': words}
    return count

# %%
df['reviewText_wordcount']=df['reviewText'].apply(word_count)
df['summary_wordcount']=df['summary'].apply(word_count)
df["reviewText_letter_count"] = df.reviewText.apply(letters)
df["summary_letter_count"] = df.summary.apply(letters)

# %%
import re

def BG(string):
    string = re.sub('[^a-zA-Z]',' ', string) 
    list1 = re.findall(r"\b[Bb]\w+|\w+[Gg]\b", string)
    return list1
BG('Bass and treble of aa song and a Bot good goog')
# Out:
# ['Bass', 'song', 'Bot', 'goog']

# %%
df["reviewText_BG"] = df.reviewText.apply(BG)
df["summary_BG"] = df.summary.apply(BG)

# %%
def not_BG(string):
    string = re.sub('[^a-zA-Z]',' ', string) #removes punctuations
    list1 = re.findall(r"\b(?![Bb])\w+(?<![Gg])\b", string) #finding words not ending with g/G and words not starting with b/B
    return list1
not_BG('Bass and treble of aa song and a Bot good goog') #example
# Out:
# ['and', 'treble', 'of', 'aa', 'and', 'a', 'good']

# %%
df["reviewText_BG"] = df.reviewText.apply(not_BG)
df["summary_BG"] = df.summary.apply(not_BG)

# %%
from nltk import word_tokenize
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def token_pos(sentence):
  sentence = re.sub("[^a-zA-Z]"," ",sentence)
  new_dict = {}
  tag = pos_tag(sentence.split())
  tag_list = list(sum(tag,()))
  new_dict = {tag_list[i]: tag_list[i+1] for i in range(0, len(tag_list), 2)}
  return new_dict

token_pos("Bhabhera has been winning the National level tournament since many years now.")
# Out:
# {'Bhabhera': 'NNP',
#  'National': 'NNP',
#  'been': 'VBN',
#  'has': 'VBZ',
#  'level': 'NN',
#  'many': 'JJ',
#  'now': 'RB',
#  'since': 'IN',
#  'the': 'DT',
#  'tournament': 'NN',
#  'winning': 'VBG',
#  'years': 'NNS'}

# %%
def token_pos2(sentence):
  sentence = re.sub("[^a-zA-Z]"," ",sentence)
  new_dict = {}
  tags = pos_tag(sentence.split())
  new_dict = {(word) : (tag) for word, tag in tags}
  return new_dict

token_pos("Bhabhera has been winning the National level tournament since many years now.")
# Out:
# {'Bhabhera': 'NNP',
#  'National': 'NNP',
#  'been': 'VBN',
#  'has': 'VBZ',
#  'level': 'NN',
#  'many': 'JJ',
#  'now': 'RB',
#  'since': 'IN',
#  'the': 'DT',
#  'tournament': 'NN',
#  'winning': 'VBG',
#  'years': 'NNS'}

# %%
def adj(sentence):
  sentence = re.sub('[^a-zA-Z]', " ", sentence)
  tag1 = pos_tag(sentence.split())
  adj1 = [(word) for word, tag in tag1 if (tag=='JJ')]
  return adj1

token_pos("Bhabhera has been winning!the National level tournament since many years now.")
# Out:
# {'Bhabhera': 'NNP',
#  'National': 'NNP',
#  'been': 'VBN',
#  'has': 'VBZ',
#  'level': 'NN',
#  'many': 'JJ',
#  'now': 'RB',
#  'since': 'IN',
#  'the': 'DT',
#  'tournament': 'NN',
#  'winning': 'VBG',
#  'years': 'NNS'}

# %%
adj(df['reviewText'][0])
# Out:
# ['first',
#  'difficult',
#  'many',
#  'powerful',
#  'counterintuitive',
#  'other',
#  'good',
#  'solid',
#  'reliable',
#  'programmable',
#  'basic',
#  'many',
#  'manual',
#  'short',
#  'ready',
#  'old']

# %%
df['adjectives_review_text'] = df['reviewText'].apply(adj)
df['adjectives_summary'] = df['summary'].apply(adj)
df['tags_review'] = df['reviewText'].apply(token_pos)
df['tags_summary'] = df['summary'].apply(token_pos)

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
def lemmatizer_pos_tags(sentence):
  lemmatizer = WordNetLemmatizer()
  print([lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(sentence)])

# %%
words = nltk.word_tokenize("Bhabhera has been winning the National level tournament since many years now.")

# %%
lemmatizer = WordNetLemmatizer()

# %%
[lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words]
# Out:
# ['Bhabhera',
#  'have',
#  'be',
#  'win',
#  'the',
#  'National',
#  'level',
#  'tournament',
#  'since',
#  'many',
#  'year',
#  'now',
#  '.']

# %%
get_wordnet_pos("the")
# Out:
# 'n'

# %%
pos_tag("good bell".split())
# Out:
# [('good', 'JJ'), ('bell', 'NN')]

# %%
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from itertools import combinations
import string

# %%
def token(sentence):
  sentence = re.sub("[^a-zA-Z]", " ", sentence)
  words = nltk.word_tokenize(sentence)
  return words

# %%
token("Bhabhera has been winning the National level tournament since many years now.")
# Out:
# ['Bhabhera',
#  'has',
#  'been',
#  'winning',
#  'the',
#  'National',
#  'level',
#  'tournament',
#  'since',
#  'many',
#  'years',
#  'now']

# %%
df['reviewText_token'] = df['reviewText'].apply(token)

# %%
df.head()
# Out:
#        reviewerID  ...                                         summary_BG
# 0  A32T2H8150OJLU  ...           [A, solid, performer, and, time, friend]
# 1  A3MAFS04ZABRGO  ...  [Price, of, GOLD, is, up, so, don, t, the, gol...
# 2  A1F1A0QQP2XVH5  ...  [Good, functionality, not, durable, like, old,...
# 3   A49R5DBXXQDE5  ...  [One, of, the, last, of, an, almost, extinct, ...
# 4  A2XRMQA6PJ5ZJ8  ...                                       [Still, the]
#
# [5 rows x 15 columns]

# %%
bagofwords = [[i] for i in list(set([y for x in df['reviewText_token'] for y in x]))]
model3 = Word2Vec(list(bagofwords), min_count=1,size= 50,workers=3, window =3, sg = 1)
bagofwords
# Out:
# [['USEFUL'],
#  ['dichotomy'],
#  ['peneverything'],
#  ['microSDHC'],
#  ['Buffet'],
#  ['movers'],
#  ['thehandle'],
#  ['tabsPost'],
#  ['instrumentOBi'],
#  ['glaze'],
#  ['unfilled'],
#  ['wheelies'],
#  ['Absent'],
#  ['materialThe'],
#  ['Cardiac'],
#  ['Electrical'],
#  ['doublefeed'],
#  ['practicalities'],
#  ['CLARITY'],
#  ['boocoodles'],
#  ['Maggie'],
#  ['ansering'],
#  ['Cobb'],
#  ['HL'],
#  ['relabeling'],
#  ['workstyle'],
#  ['badgers'],
#  ['imposible'],
#  ['comedy'],
#  ['skater'],
#  ['chiseled'],
#  ['STYLOPHILE'],
#  ['Firefox'],
#  ['USDA'],
#  ['veggie'],
#  ['Comments'],
#  ['upto'],
#  ['battles'],
#  ['mispronunciation'],
#  ['Cosco'],
#  ['wisp'],
#  ['LETTERS'],
#  ['Cautions'],
#  ['drumroll'],
#  ['youAvery'],
#  ['lord'],
#  ['kinko'],
#  ['phoning'],
#  ['dissassemble'],
#  ['QY'],
#  ['rechargable'],
#  ['Karim'],
#  ['chiropractor'],
#  ['branch'],
#  ['BLOW'],
#  ['forecasts'],
#  ['OverallThe'],
#  ['printsFaxSingle'],
#  ['nw'],
#  ['SIZED'],
#  ['microscopic'],
#  ['greetings'],
#  ['Retractability'],
#  ['MAGENTA'],
#  ['shakey'],
#  ['Translucent'],
#  ['uptopia'],
#  ['RANGE'],
#  ['enlough'],
#  ['tone'],
#  ['allDelivery'],
#  ['meetups'],
#  ['temperament'],
#  ['Muscle'],
#  ['couponer'],
#  ['notch'],
#  ['Fireworx'],
#  ['Shaking'],
#  ['greatful'],
#  ['Downgrading'],
#  ['fiveTeacher'],
#  ['oftent'],
#  ['Weighing'],
#  ['Drab'],
#  ['Labelworkds'],
#  ['tkind'],
#  ['desire'],
#  ['PrintingPrinting'],
#  ['Withstands'],
#  ['Title'],
#  ['Cotton'],
#  ['Perforations'],
#  ['organizational'],
#  ['FF'],
#  ['Pakcage'],
#  ['pray'],
#  ['dpiConnectivity'],
#  ['thermostats'],
#  ['hawing'],
#  ['blood'],
#  ['last'],
#  ['wick'],
#  ['governor'],
#  ['Motorola'],
#  ['ageless'],
#  ['rebrands'],
#  ['Ingredients'],
#  ['HTU'],
#  ['Frameless'],
#  ['employed'],
#  ['repalce'],
#  ['Slide'],
#  ['doodling'],
#  ['oxidized'],
#  ['Hercules'],
#  ['insecurely'],
#  ['Skip'],
#  ['elicits'],
#  ['Versions'],
#  ['mite'],
#  ['thischecked'],
#  ['scrather'],
#  ['relieving'],
#  ['tend'],
#  ['folders'],
#  ['IMAK'],
#  ['ould'],
#  ['adapterOver'],
#  ['repeats'],
#  ['uneconomical'],
#  ['Streaking'],
#  ['syrup'],
#  ['italicized'],
#  ['Clickster'],
#  ['ALso'],
#  ['depression'],
#  ['Nigel'],
#  ['seared'],
#  ['Existing'],
#  ['conditionslike'],
#  ['notebinder'],
#  ['WR'],
#  ['influencing'],
#  ['Sez'],
#  ['Fischer'],
#  ['strengh'],
#  ['redeye'],
#  ['Meads'],
#  ['closed'],
#  ['nagware'],
#  ['Defect'],
#  ['keycase'],
#  ['stealing'],
#  ['upchuck'],
#  ['overspray'],
#  ['Speedily'],
#  ['youOverall'],
#  ['itEasily'],
#  ['asEpson'],
#  ['hang'],
#  ['grouch'],
#  ['crocheting'],
#  ['some'],
#  ['Tour'],
#  ['Background'],
#  ['Thecartridges'],
#  ['needle'],
#  ['allllll'],
#  ['mashing'],
#  ['harware'],
#  ['rangeAAA'],
#  ['turnaround'],
#  ['Sales'],
#  ['coax'],
#  ['efficacy'],
#  ['PRESHARPENED'],
#  ['DUH'],
#  ['vitals'],
#  ['Adware'],
#  ['RINGS'],
#  ['lunches'],
#  ['Twisting'],
#  ['inconspicuous'],
#  ['basketball'],
#  ['PictBridgeA'],
#  ['phantom'],
#  ['misfed'],
#  ['SummaryThe'],
#  ['indoors'],
#  ['unexceptional'],
#  ['hesitancy'],
#  ['executive'],
#  ['distressingly'],
#  ['tares'],
#  ['slips'],
#  ['theeneloop'],
#  ['ISN'],
#  ['detours'],
#  ['Thousands'],
#  ['pushers'],
#  ['encoding'],
#  ['belches'],
#  ['Bascom'],
#  ['nosing'],
#  ['RadioShack'],
#  ['secondarily'],
#  ['abasic'],
#  ['proclaim'],
#  ['wiggly'],
#  ['SAD'],
#  ['Reviewer'],
#  ['inadequate'],
#  ['Excuse'],
#  ['SEARCH'],
#  ['hound'],
#  ['Altered'],
#  ['buttplug'],
#  ['uverse'],
#  ['devalue'],
#  ['promote'],
#  ['serif'],
#  ['LIGHTED'],
#  ['acquired'],
#  ['wheels'],
#  ['swerve'],
#  ['obligations'],
#  ['samples'],
#  ['Snapscanner'],
#  ['counterfeiting'],
#  ['Realize'],
#  ['outgoingExisting'],
#  ['affords'],
#  ['Tip'],
#  ['disconcerted'],
#  ['mutual'],
#  ['pard'],
#  ['Adhering'],
#  ['clearOK'],
#  ['indexes'],
#  ['proctor'],
#  ['m'],
#  ['separations'],
#  ['ratchets'],
#  ['magna'],
#  ['energizer'],
#  ['SEPERATES'],
#  ['ENORMOUS'],
#  ['sanitary'],
#  ['inbreeding'],
#  ['Gripe'],
#  ['ATROCIOUS'],
#  ['Shine'],
#  ['RNs'],
#  ['seeeeee'],
#  ['KbpsColor'],
#  ['ELECTRONIC'],
#  ['auxilary'],
#  ['laptopdid'],
#  ['placard'],
#  ['IssuesI'],
#  ['tomato'],
#  ['surprising'],
#  ['Whirl'],
#  ['glops'],
#  ['mowing'],
#  ['paperFor'],
#  ['suppossed'],
#  ['older'],
#  ['wandering'],
#  ['groupies'],
#  ['Chrismtas'],
#  ['ready'],
#  ['translated'],
#  ['Molecular'],
#  ['netflix'],
#  ['Thickness'],
#  ['completion'],
#  ['likeWhite'],
#  ['minces'],
#  ['Learning'],
#  ['Nuts'],
#  ['cheese'],
#  ['SquareTrade'],
#  ['FORMAT'],
#  ['UUUgh'],
#  ['cattle'],
#  ['UNATTENDED'],
#  ['thro'],
#  ['quaillty'],
#  ['laboriously'],
#  ['demos'],
#  ['columms'],
#  ['magetic'],
#  ['fit'],
#  ['Blatant'],
#  ['Designer'],
#  ['Directive'],
#  ['frugality'],
#  ['complet'],
#  ['Streaks'],
#  ['compaines'],
#  ['iDevice'],
#  ['printingBigger'],
#  ['theTEKwriterUSA'],
#  ['aims'],
#  ['Stereo'],
#  ['topnotch'],
#  ['bough'],
#  ['authorize'],
#  ['Mountainview'],
#  ['Pitt'],
#  ['Bekins'],
#  ['rims'],
#  ['graininess'],
#  ['Heater'],
#  ['Razenettes'],
#  ['Applicator'],
#  ['Spelling'],
#  ['countersinks'],
#  ['leftmost'],
#  ['steak'],
#  ['rollerballs'],
#  ['Nickel'],
#  ['LM'],
#  ['experimenting'],
#  ['Kiddo'],
#  ['surpasses'],
#  ['Emotions'],
#  ['Chances'],
#  ['stang'],
#  ['NameDirectory'],
#  ['counters'],
#  ['afforadable'],
#  ['mchine'],
#  ['molly'],
#  ['inexplicable'],
#  ['compounds'],
#  ['Permit'],
#  ['RESOLUTION'],
#  ['Floortex'],
#  ['trashed'],
#  ['Techno'],
#  ['readiness'],
#  ['Certified'],
#  ['unready'],
#  ['LEAKING'],
#  ['Convert'],
#  ['orgainizing'],
#  ['Parties'],
#  ['App'],
#  ['ENERGY'],
#  ['dilbert'],
#  ['glassed'],
#  ['smoky'],
#  ['constricted'],
#  ['scouting'],
#  ['Diff'],
#  ['payment'],
#  ['meanings'],
#  ['MISALIGNED'],
#  ['bight'],
#  ['Netflix'],
#  ['refillsMinuses'],
#  ['Accepted'],
#  ['ISO'],
#  ['Skydrive'],
#  ['iPhoto'],
#  ['Pads'],
#  ['recallibration'],
#  ['Bills'],
#  ['KB'],
#  ['averages'],
#  ['Ali'],
#  ['recognizing'],
#  ['venting'],
#  ['Stratitec'],
#  ['sizeThis'],
#  ['Elmora'],
#  ['Spudman'],
#  ['WorkHorse'],
#  ['PHone'],
#  ['OK'],
#  ['di'],
#  ['surreal'],
#  ['probe'],
#  ['VuPoint'],
#  ['Elastic'],
#  ['baggie'],
#  ['childhood'],
#  ['Caloric'],
#  ['unconventional'],
#  ['outcomes'],
#  ['oneSamsung'],
#  ['Fairbanks'],
#  ['isIt'],
#  ['Targeted'],
#  ['secondhand'],
#  ['Published'],
#  ['pissed'],
#  ['gasp'],
#  ['POffice'],
#  ['misapplied'],
#  ['sillier'],
#  ['YesQuality'],
#  ['bungs'],
#  ['wireing'],
#  ['ProfessionalMac'],
#  ['PERFECTLY'],
#  ['Ponies'],
#  ['Monthy'],
#  ['Glory'],
#  ['Rockwell'],
#  ['softkeys'],
#  ['laborious'],
#  ['Raise'],
#  ['feedingI'],
#  ['Nobel'],
#  ['buyPilot'],
#  ['batteriesCorded'],
#  ['throat'],
#  ['ascending'],
#  ['printa'],
#  ['Printed'],
#  ['notebooking'],
#  ['bestsellers'],
#  ['minutesCost'],
#  ['misread'],
#  ['Tighter'],
#  ['Pearl'],
#  ['Wing'],
#  ['CMB'],
#  ['Previously'],
#  ['Brothers'],
#  ['integrity'],
#  ['clings'],
#  ['relocations'],
#  ['ancestors'],
#  ['outskirts'],
#  ['Individual'],
#  ['foodstuffs'],
#  ['confesses'],
#  ['flap'],
#  ['edgeMinuses'],
#  ['CIS'],
#  ['Nspire'],
#  ['foreigner'],
#  ['mommys'],
#  ['Piles'],
#  ['GE'],
#  ['hoops'],
#  ['Assurance'],
#  ['chemistry'],
#  ['Stream'],
#  ['cacophony'],
#  ['plate'],
#  ['PEEL'],
#  ['Heathrow'],
#  ['withToshiba'],
#  ['Takentried'],
#  ['nealo'],
#  ['pumpkin'],
#  ['liken'],
#  ['victorious'],
#  ['Hundred'],
#  ['bugger'],
#  ['valid'],
#  ['Gus'],
#  ['TVM'],
#  ['recommendScotch'],
#  ['junky'],
#  ['pl'],
#  ['Only'],
#  ['QM'],
#  ['ong'],
#  ['yester'],
#  ['Blaster'],
#  ['enervating'],
#  ['connections'],
#  ['wildly'],
#  ['bizzaro'],
#  ['knocked'],
#  ['smartly'],
#  ['delicates'],
#  ['Uhhh'],
#  ['Leek'],
#  ['clanky'],
#  ['voucher'],
#  ['Marker'],
#  ['idiomatic'],
#  ['opposed'],
#  ['pits'],
#  ['unmercifully'],
#  ['Torn'],
#  ['strung'],
#  ['territorial'],
#  ['Labelerthat'],
#  ['takestwo'],
#  ['andunpeel'],
#  ['Depot'],
#  ['enlargeMaximum'],
#  ['CDO'],
#  ['hase'],
#  ['lablels'],
#  ['pricesWithout'],
#  ['whole'],
#  ['steadfastly'],
#  ['outsourced'],
#  ['vacuoles'],
#  ['baggage'],
#  ['ecological'],
#  ['geography'],
#  ['etsy'],
#  ['overheating'],
#  ['GENERATION'],
#  ['dictionay'],
#  ['MUST'],
#  ['Fusion'],
#  ['raisers'],
#  ['ROW'],
#  ['embodied'],
#  ['chat'],
#  ['notion'],
#  ['soI'],
#  ['corporation'],
#  ['harm'],
#  ['pirate'],
#  ['postmaster'],
#  ['MSOffice'],
#  ['iLabel'],
#  ['clickit'],
#  ['undercover'],
#  ['Steadler'],
#  ['athlete'],
#  ['theDuck'],
#  ['relaminating'],
#  ['MBA'],
#  ['realizing'],
#  ['silkscreen'],
#  ['YLD'],
#  ['looksCons'],
#  ['il'],
#  ['Washington'],
#  ['lil'],
#  ['sicking'],
#  ['groomed'],
#  ['ibook'],
#  ['aross'],
#  ['Photoreview'],
#  ['seventh'],
#  ['feces'],
#  ['parterned'],
#  ['hairy'],
#  ['retrofitting'],
#  ['Hilton'],
#  ['incorporated'],
#  ['TRAM'],
#  ['Fisher'],
#  ['helpfulness'],
#  ['lifters'],
#  ['GRANTED'],
#  ['resolvedthe'],
#  ['prefilled'],
#  ['touches'],
#  ['explicit'],
#  ['sbest'],
#  ['eraseNot'],
#  ['Squashing'],
#  ['RePockets'],
#  ['Autolam'],
#  ['Forms'],
#  ['prior'],
#  ['elongated'],
#  ['tinnier'],
#  ['sense'],
#  ['humorous'],
#  ['magnates'],
#  ['Precautions'],
#  ['Marcy'],
#  ['dispenserand'],
#  ['offsize'],
#  ['printerThese'],
#  ['displayMemory'],
#  ['respect'],
#  ['preforated'],
#  ['vise'],
#  ['promotes'],
#  ['UTF'],
#  ['exhibited'],
#  ['interchangable'],
#  ['PrintNew'],
#  ['pencilto'],
#  ['printingtelephone'],
#  ['artsy'],
#  ['machinery'],
#  ['number'],
#  ['TeleZapper'],
#  ['replug'],
#  ['Infact'],
#  ['FEES'],
#  ['unfasten'],
#  ['kickstarter'],
#  ['hummus'],
#  ['colot'],
#  ['dismally'],
#  ['minutia'],
#  ['sergers'],
#  ['expandables'],
#  ['broterh'],
#  ['Match'],
#  ['Beetle'],
#  ['copiesBit'],
#  ['Lousy'],
#  ['RENAME'],
#  ['Workbooks'],
#  ['tiffs'],
#  ['disintegration'],
#  ['Economy'],
#  ['Four'],
#  ['Svenson'],
#  ['highlights'],
#  ['clouds'],
#  ['WORKBOOK'],
#  ['aubjects'],
#  ['silkiness'],
#  ['inpatient'],
#  ['computerswhen'],
#  ['LOTeasier'],
#  ['swelts'],
#  ['HTC'],
#  ['ambitions'],
#  ['versionSmead'],
#  ['discourages'],
#  ['tribute'],
#  ['Acrylic'],
#  ['beginnings'],
#  ['staplersIt'],
#  ['hub'],
#  ['friends'],
#  ['Heavier'],
#  ['earset'],
#  ['rebuilt'],
#  ['CONSUMPTION'],
#  ['StaplerOVERVIEW'],
#  ['Jeep'],
#  ['Carry'],
#  ['Women'],
#  ['discounts'],
#  ['helpfulIn'],
#  ['whacky'],
#  ['crook'],
#  ['Amex'],
#  ['texas'],
#  ['photoshop'],
#  ['Testament'],
#  ['repels'],
#  ['elation'],
#  ['enviro'],
#  ['blemish'],
#  ['caked'],
#  ['stride'],
#  ['LEARNED'],
#  ['Workforce'],
#  ['splurged'],
#  ['grapes'],
#  ['screeched'],
#  ['Chan'],
#  ['nubbier'],
#  ['Telo'],
#  ['Groovy'],
#  ['behemothEpson'],
#  ['kinder'],
#  ['sailor'],
#  ['sharpee'],
#  ['readerThe'],
#  ['speakerphone'],
#  ['ballroom'],
#  ['meaninglessWhat'],
#  ['impair'],
#  ['nevermind'],
#  ['meaning'],
#  ['ColorChecker'],
#  ['backordered'],
#  ['autographs'],
#  ['FSC'],
#  ['Absolutly'],
#  ['Avon'],
#  ['http'],
#  ['UPDATEWe'],
#  ['Highlight'],
#  ['hyperlinked'],
#  ['TheDYMO'],
#  ['glare'],
#  ['Single'],
#  ['estrogents'],
#  ['choises'],
#  ['getsoft'],
#  ['scooped'],
#  ['EXTREMELY'],
#  ['Windex'],
#  ['graters'],
#  ['RIng'],
#  ['incandescent'],
#  ['butterfingers'],
#  ['circumstances'],
#  ['preserves'],
#  ['chugathon'],
#  ['hallucination'],
#  ['SubwooferI'],
#  ['colorStar'],
#  ['MSCONFIG'],
#  ['clones'],
#  ['aqm'],
#  ['CMYK'],
#  ['connectionSize'],
#  ['Understandably'],
#  ['hexagons'],
#  ['MOUNTABLE'],
#  ['invigorated'],
#  ['Flash'],
#  ['DOCUMENT'],
#  ['BubbleJet'],
#  ['Answers'],
#  ['edu'],
#  ['Buzzed'],
#  ['pithy'],
#  ['swung'],
#  ['USandKensington'],
#  ['Benefits'],
#  ['highIf'],
#  ['OBITALK'],
#  ['atrocious'],
#  ['lovin'],
#  ['Tacker'],
#  ['thereon'],
#  ['relayed'],
#  ['papery'],
#  ['rarer'],
#  ['adopted'],
#  ['blobbed'],
#  ['SHPG'],
#  ['YardHOW'],
#  ['airprint'],
#  ['risks'],
#  ['scarring'],
#  ['Graphs'],
#  ['Displayon'],
#  ['overlying'],
#  ['overpowering'],
#  ['Econo'],
#  ['sheath'],
#  ['Celebrity'],
#  ['maneuverability'],
#  ['scrolling'],
#  ['Whe'],
#  ['phobe'],
#  ['twenties'],
#  ['GCS'],
#  ['Pinaccle'],
#  ['halting'],
#  ['DESPITE'],
#  ['NEVERTHELESSEven'],
#  ['logitech'],
#  ['million'],
#  ['fuser'],
#  ['easter'],
#  ['interchanged'],
#  ['exercising'],
#  ['uline'],
#  ['modeThe'],
#  ['unhint'],
#  ['overmold'],
#  ['appearance'],
#  ['dihydrate'],
#  ['ruler'],
#  ['playhouse'],
#  ['ony'],
#  ['ethics'],
#  ['Wonderhorse'],
#  ['arteries'],
#  ['uncomfortable'],
#  ['godsend'],
#  ['College'],
#  ['pageful'],
#  ['Upstairs'],
#  ['HARM'],
#  ['expensiveand'],
#  ['LongLife'],
#  ['harks'],
#  ['misled'],
#  ['con'],
#  ['CIFS'],
#  ['Snapped'],
#  ['changable'],
#  ['bibliophile'],
#  ['MANILA'],
#  ['LITTEL'],
#  ['wise'],
#  ['bling'],
#  ['Taxact'],
#  ['thes'],
#  ['Comparisons'],
#  ['cooks'],
#  ['inhibits'],
#  ['SkyDrive'],
#  ['blinks'],
#  ['module'],
#  ['pelvic'],
#  ['Whooo'],
#  ['clackier'],
#  ['erection'],
#  ['atackornail'],
#  ['outweighs'],
#  ['wmight'],
#  ['reqts'],
#  ['andput'],
#  ['abbreviated'],
#  ['darn'],
#  ['redwood'],
#  ['usingold'],
#  ['salsa'],
#  ['Take'],
#  ['logistical'],
#  ['unease'],
#  ['SYSTEMThe'],
#  ['answerer'],
#  ['elmer'],
#  ['squat'],
#  ['Occasional'],
#  ['Johns'],
#  ['Nature'],
#  ['diffrent'],
#  ['bitt'],
#  ['COULD'],
#  ['directors'],
#  ['politicians'],
#  ['Vue'],
#  ['plunger'],
#  ['trickiest'],
#  ['ADDRESSED'],
#  ['cooperative'],
#  ['NoteBinder'],
#  ['BANKERS'],
#  ['Maya'],
#  ['intent'],
#  ['arcanely'],
#  ['Al'],
#  ['silly'],
#  ['overpaying'],
#  ['EditionMac'],
#  ['Dip'],
#  ['lenths'],
#  ['absorbing'],
#  ['Clicky'],
#  ['wasteland'],
#  ['willannounce'],
#  ['wasi'],
#  ['cartages'],
#  ['LG'],
#  ['flatter'],
#  ['PLPP'],
#  ['armrests'],
#  ['FREELY'],
#  ['Woody'],
#  ['ebook'],
#  ['Cubic'],
#  ['porosity'],
#  ['CopyCollateAdjustable'],
#  ['ben'],
#  ['SCANNER'],
#  ['impatient'],
#  ['archeologists'],
#  ['Requires'],
#  ['parachute'],
#  ['listingAvery'],
#  ['stuffCONS'],
#  ['aviation'],
#  ['Relatedly'],
#  ['CardsIt'],
#  ['mildly'],
#  ['roob'],
#  ['Defects'],
#  ['MagnaSafe'],
#  ['voluntarily'],
#  ['minnesota'],
#  ['appearAnother'],
#  ['SCRUB'],
#  ['comb'],
#  ['jacks'],
#  ['PaperandMead'],
#  ['paypal'],
#  ['shaprener'],
#  ['deductible'],
#  ['soundtrack'],
#  ['Downgrades'],
#  ['LXre'],
#  ['installments'],
#  ['identically'],
#  ['Whitea'],
#  ['rippled'],
#  ['Cadres'],
#  ['Shredderneeds'],
#  ['moisture'],
#  ['holics'],
#  ['Oslo'],
#  ['Tini'],
#  ['stupid'],
#  ['copiercons'],
#  ['buries'],
#  ['BEFORE'],
#  ['LinkyoExpress'],
#  ['Fellowed'],
#  ['shadowed'],
#  ['Mind'],
#  ['nx'],
#  ['EMT'],
#  ['figuring'],
#  ['REMAIN'],
#  ['Lord'],
#  ['wattage'],
#  ['fanningoperation'],
#  ['Moore'],
#  ['noisytakes'],
#  ['accommodations'],
#  ['Receipts'],
#  ['penAcid'],
#  ['TheFaber'],
#  ['piece'],
#  ['plactic'],
#  ['involving'],
#  ['fives'],
#  ['DISCLOSURE'],
#  ['CardMMCplusMMCmobile'],
#  ['HNY'],
#  ['sceneDress'],
#  ['obliterated'],
#  ['colorStandard'],
#  ['TheWestcott'],
#  ['fruition'],
#  ['queueing'],
#  ['underinflated'],
#  ['tempy'],
#  ['Every'],
#  ['devise'],
#  ['ofPaper'],
#  ['stockpile'],
#  ['Lowe'],
#  ['seedlings'],
#  ['headrest'],
#  ['versatilepros'],
#  ['TEKWriter'],
#  ['mitt'],
#  ['requests'],
#  ['Smencilsas'],
#  ['meter'],
#  ['bluntly'],
#  ['Ensure'],
#  ['costEventually'],
#  ['Keeps'],
#  ['seamstress'],
#  ['straignt'],
#  ['paperThis'],
#  ['emptied'],
#  ['overcrowd'],
#  ['deceptive'],
#  ['voluntary'],
#  ['recomendations'],
#  ['Lamingtons'],
#  ['conference'],
#  ['Romanian'],
#  ['Distinctive'],
#  ['admik'],
#  ['transparant'],
#  ['style'],
#  ['Beware'],
#  ['Skywalker'],
#  ['BUTTON'],
#  ['Trap'],
#  ['perspires'],
#  ['STANZA'],
#  ['unmarried'],
#  ['ABSOLUTELY'],
#  ['buffered'],
#  ['Simmons'],
#  ['pastor'],
#  ['inspects'],
#  ['anonymously'],
#  ['felty'],
#  ['Frames'],
#  ['spelled'],
#  ['unobstructed'],
#  ['Autofeeder'],
#  ['avoid'],
#  ['ocd'],
#  ['Blunt'],
#  ['drivesworked'],
#  ['commensurately'],
#  ['offset'],
#  ['officewireless'],
#  ['Voicemail'],
#  ['TRANSLUCENT'],
#  ...]

# %%
for i in bagofwords[0:20]:
  for j in bagofwords[0:20]:
    if j>i:
      print(i[0],j[0],' : ',model3.wv.similarity(i[0],j[0]))
    else:
      continue
# Out:
# USEFUL dichotomy  :  -0.082249396
# USEFUL peneverything  :  0.11623478
# USEFUL microSDHC  :  -0.048493743
# USEFUL movers  :  0.03162412
# USEFUL thehandle  :  -0.06761088
# USEFUL tabsPost  :  -0.1750729
# USEFUL instrumentOBi  :  -0.17439325
# USEFUL glaze  :  -0.0062765745
# USEFUL unfilled  :  0.316202
# USEFUL wheelies  :  -0.06749297
# USEFUL materialThe  :  -0.12981555
# USEFUL doublefeed  :  -0.21622127
# USEFUL practicalities  :  0.13624439
# USEFUL boocoodles  :  0.15764272
# dichotomy peneverything  :  -0.14748491
# dichotomy microSDHC  :  -0.037250668
# dichotomy movers  :  0.1430973
# dichotomy thehandle  :  0.157986
# dichotomy tabsPost  :  -0.43491375
# dichotomy instrumentOBi  :  -0.23539902
# dichotomy glaze  :  -0.10423647
# dichotomy unfilled  :  -0.0687968
# dichotomy wheelies  :  -0.13952504
# dichotomy materialThe  :  0.17003225
# dichotomy doublefeed  :  0.08240356
# dichotomy practicalities  :  0.07669377
# peneverything thehandle  :  -0.20602787
# peneverything tabsPost  :  -0.16659297
# peneverything unfilled  :  -0.055864036
# peneverything wheelies  :  -0.09673958
# peneverything practicalities  :  0.13289903
# microSDHC peneverything  :  -0.03290297
# microSDHC movers  :  -0.33440354
# microSDHC thehandle  :  -0.024355827
# microSDHC tabsPost  :  0.06109816
# microSDHC unfilled  :  -0.12887645
# microSDHC wheelies  :  -0.12642205
# microSDHC practicalities  :  0.0801226
# Buffet USEFUL  :  -0.0024914655
# Buffet dichotomy  :  -0.28476244
# Buffet peneverything  :  -0.19638644
# Buffet microSDHC  :  0.048908286
# Buffet movers  :  0.029928885
# Buffet thehandle  :  0.15698256
# Buffet tabsPost  :  0.16228671
# Buffet instrumentOBi  :  0.12685797
# Buffet glaze  :  -0.15466756
# Buffet unfilled  :  0.05356288
# Buffet wheelies  :  0.078545325
# Buffet materialThe  :  -0.12291388
# Buffet Cardiac  :  0.15043178
# Buffet Electrical  :  -0.12822683
# Buffet doublefeed  :  0.08510086
# Buffet practicalities  :  0.07278776
# Buffet CLARITY  :  -0.14774264
# Buffet boocoodles  :  -0.060456917
# movers peneverything  :  -0.13980885
# movers thehandle  :  -0.03669733
# movers tabsPost  :  0.035454147
# movers unfilled  :  0.27600896
# movers wheelies  :  0.019905737
# movers practicalities  :  0.11986628
# thehandle unfilled  :  -0.026397806
# thehandle wheelies  :  -0.16398843
# tabsPost thehandle  :  0.18909636
# tabsPost unfilled  :  0.06630814
# tabsPost wheelies  :  0.24585779
# instrumentOBi peneverything  :  -0.1808008
# instrumentOBi microSDHC  :  0.07683191
# instrumentOBi movers  :  -0.024963625
# instrumentOBi thehandle  :  -0.07430891
# instrumentOBi tabsPost  :  0.43100077
# instrumentOBi unfilled  :  0.08810182
# instrumentOBi wheelies  :  0.24009672
# instrumentOBi materialThe  :  0.06983041
# instrumentOBi practicalities  :  -0.09526791
# glaze peneverything  :  0.032484043
# glaze microSDHC  :  0.22427854
# glaze movers  :  -0.26863435
# glaze thehandle  :  -0.046631325
# glaze tabsPost  :  0.043714862
# glaze instrumentOBi  :  -0.20634326
# glaze unfilled  :  -0.049128756
# glaze wheelies  :  -0.03422566
# glaze materialThe  :  -0.06822168
# glaze practicalities  :  0.004764111
# unfilled wheelies  :  0.18190366
# Absent USEFUL  :  0.07890012
# Absent dichotomy  :  -0.072383195
# Absent peneverything  :  0.18549171
# Absent microSDHC  :  -0.09070271
# Absent Buffet  :  0.104016945
# Absent movers  :  -0.15036517
# Absent thehandle  :  0.14462678
# Absent tabsPost  :  0.029816885
# Absent instrumentOBi  :  0.14350462
# Absent glaze  :  0.13429198
# Absent unfilled  :  0.11625075
# Absent wheelies  :  0.09037741
# Absent materialThe  :  0.18567687
# Absent Cardiac  :  0.27676365
# Absent Electrical  :  0.04609971
# Absent doublefeed  :  -0.16389447
# Absent practicalities  :  0.10535514
# Absent CLARITY  :  -0.30152968
# Absent boocoodles  :  0.19403946
# materialThe peneverything  :  0.1628564
# materialThe microSDHC  :  -0.06583151
# materialThe movers  :  -0.0718414
# materialThe thehandle  :  -0.0491051
# materialThe tabsPost  :  -0.20164274
# materialThe unfilled  :  -0.024516111
# materialThe wheelies  :  -0.10237701
# materialThe practicalities  :  -0.052274603
# Cardiac USEFUL  :  0.08325813
# Cardiac dichotomy  :  0.02087323
# Cardiac peneverything  :  0.06790661
# Cardiac microSDHC  :  -0.10557676
# Cardiac movers  :  0.1537107
# Cardiac thehandle  :  0.10316145
# Cardiac tabsPost  :  0.019182837
# Cardiac instrumentOBi  :  -0.13299426
# Cardiac glaze  :  -0.028474309
# Cardiac unfilled  :  0.048028037
# Cardiac wheelies  :  0.099836625
# Cardiac materialThe  :  -0.08363398
# Cardiac Electrical  :  0.038121156
# Cardiac doublefeed  :  -0.1021009
# Cardiac practicalities  :  0.119190544
# Cardiac boocoodles  :  -0.041958306
# Electrical USEFUL  :  -0.039620556
# Electrical dichotomy  :  -0.14604641
# Electrical peneverything  :  -0.08102794
# Electrical microSDHC  :  -0.0025294698
# Electrical movers  :  0.08363009
# Electrical thehandle  :  -0.20990533
# Electrical tabsPost  :  0.23770042
# Electrical instrumentOBi  :  0.25200862
# Electrical glaze  :  0.18591098
# Electrical unfilled  :  0.031528253
# Electrical wheelies  :  0.0491951
# Electrical materialThe  :  0.028245736
# Electrical doublefeed  :  -0.0053257113
# Electrical practicalities  :  0.036665563
# Electrical boocoodles  :  0.1732034
# doublefeed peneverything  :  0.01948629
# doublefeed microSDHC  :  0.3106938
# doublefeed movers  :  0.11286517
# doublefeed thehandle  :  -0.055992734
# doublefeed tabsPost  :  0.06446962
# doublefeed instrumentOBi  :  0.15469095
# doublefeed glaze  :  0.15469614
# doublefeed unfilled  :  -0.14216974
# doublefeed wheelies  :  0.07416026
# doublefeed materialThe  :  -0.121068574
# doublefeed practicalities  :  0.2913749
# practicalities thehandle  :  -0.054620825
# practicalities tabsPost  :  -0.14863305
# practicalities unfilled  :  0.186401
# practicalities wheelies  :  -0.07630462
# CLARITY USEFUL  :  -0.15362307
# CLARITY dichotomy  :  -0.044963665
# CLARITY peneverything  :  -0.012548418
# CLARITY microSDHC  :  0.09376269
# CLARITY movers  :  -0.14092441
# CLARITY thehandle  :  0.021411477
# CLARITY tabsPost  :  -0.06027303
# CLARITY instrumentOBi  :  -0.085462235
# CLARITY glaze  :  0.027447179
# CLARITY unfilled  :  -0.13904464
# CLARITY wheelies  :  -0.103041954
# CLARITY materialThe  :  0.05237886
# CLARITY Cardiac  :  0.08268318
# CLARITY Electrical  :  -0.26872274
# CLARITY doublefeed  :  0.28210032
# CLARITY practicalities  :  0.11899397
# CLARITY boocoodles  :  0.12106847
# boocoodles dichotomy  :  -0.13415524
# boocoodles peneverything  :  0.048119176
# boocoodles microSDHC  :  0.022905482
# boocoodles movers  :  0.115190044
# boocoodles thehandle  :  0.115590885
# boocoodles tabsPost  :  0.019549295
# boocoodles instrumentOBi  :  -0.014977656
# boocoodles glaze  :  0.32310334
# boocoodles unfilled  :  -0.22984661
# boocoodles wheelies  :  -0.04635912
# boocoodles materialThe  :  -0.114044815
# boocoodles doublefeed  :  0.109341614
# boocoodles practicalities  :  -0.09946832
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
